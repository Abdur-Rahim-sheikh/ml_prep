# %% [markdown]
# # Tutorial 7: ARGA & ARVGA
#
# Paper:
# * [Adversarially Regularized Graph Autoencoder for Graph Embedding](https://www.ijcai.org/Proceedings/2018/0362.pdf)
#
# Code:
#  * [ARGA & ARVGA](https://pytorch-geometric.readthedocs.io/en/latest/_modules/torch_geometric/nn/models/autoencoder.html)
#  * [Example on clustering](https://github.com/rusty1s/pytorch_geometric/blob/master/examples/argva_node_clustering.py)

# %%
import os
import torch
os.environ['TORCH'] = torch.__version__
print(torch.__version__)

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git
# Out:
# 1.12.0+cu116

# %% [markdown]
# ## Imports

# %%
import os.path as osp
import torch
import torch.nn.functional as F
from sklearn.cluster import KMeans
from sklearn.metrics.cluster import (v_measure_score, homogeneity_score, completeness_score)
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import torch_geometric.transforms as T
from torch_geometric.datasets import Planetoid
from torch_geometric.nn import GCNConv
from torch_geometric.nn.models.autoencoder import ARGVA
from torch_geometric.utils import train_test_split_edges

# %%
use_cuda = False

# %% [markdown]
# ## Define the dataset

# %% [markdown]
# Download the dataset

# %%
dataset = Planetoid('dataset', 'Cora', transform=T.NormalizeFeatures())
data = dataset.get(0)
# Out:
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.x
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.tx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.allx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.y
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ty
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ally
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.graph
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.test.index
# Processing...
# Done!

# %% [markdown]
# Get the number of nodes

# %%
num_nodes = data.x.shape[0]

# %% [markdown]
# Create the train/val/test data

# %%
data.train_mask = data.val_mask = data.test_mask = None
data = train_test_split_edges(data)
data
# Out:
# /home/abir/miniconda3/envs/pygdebias_env/lib/python3.9/site-packages/torch_geometric/deprecation.py:26: UserWarning: 'train_test_split_edges' is deprecated, use 'transforms.RandomLinkSplit' instead
#   warnings.warn(out)
# Data(x=[2708, 1433], y=[2708], val_pos_edge_index=[2, 263], test_pos_edge_index=[2, 527], train_pos_edge_index=[2, 8976], train_neg_adj_mask=[2708, 2708], val_neg_edge_index=[2, 263], test_neg_edge_index=[2, 527])

# %% [markdown]
# ## Define the model

# %% [markdown]
# Define the encoder classes (the same as in `Tutorial 6`)

# %%
class VEncoder(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super(VEncoder, self).__init__()
        self.conv1 = GCNConv(in_channels, 2 * out_channels, cached=True)
        self.conv_mu = GCNConv(2 * out_channels, out_channels, cached=True)
        self.conv_logstd = GCNConv(2 * out_channels, out_channels, cached=True)

    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index))
        return self.conv_mu(x, edge_index), self.conv_logstd(x, edge_index)

# %% [markdown]
# Define the discriminator class

# %%
class Discriminator(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels):
        super(Discriminator, self).__init__()
        self.lin1 = torch.nn.Linear(in_channels, hidden_channels)
        self.lin2 = torch.nn.Linear(hidden_channels, hidden_channels)
        self.lin3 = torch.nn.Linear(hidden_channels, out_channels)

    def forward(self, x):
        x = F.relu(self.lin1(x))
        x = F.relu(self.lin2(x))
        x = self.lin3(x)
        return x

# %% [markdown]
# Define the training algorithm

# %%
def train():
    model.train()
    encoder_optimizer.zero_grad()
    
    z = model.encode(data.x, data.train_pos_edge_index)

    for i in range(5):
        idx = range(num_nodes)  
        discriminator.train()
        discriminator_optimizer.zero_grad()
        discriminator_loss = model.discriminator_loss(z[idx]) # Comment
        discriminator_loss.backward(retain_graph=True)
        discriminator_optimizer.step()
 
    loss = 0
    loss = loss + model.reg_loss(z)  # Comment
    
    loss = loss + model.recon_loss(z, data.train_pos_edge_index)
    loss = loss + (1 / data.num_nodes) * model.kl_loss()
    loss.backward()

    encoder_optimizer.step()
    
    return loss

# %% [markdown]
# Define a training test method

# %%
@torch.no_grad()
def test():
    model.eval()
    z = model.encode(data.x, data.train_pos_edge_index)

    # Cluster embedded values using k-means.
    kmeans_input = z.cpu().numpy()
    kmeans = KMeans(n_clusters=7, random_state=0).fit(kmeans_input)
    pred = kmeans.predict(kmeans_input)

    labels = data.y.cpu().numpy()
    completeness = completeness_score(labels, pred)
    hm = homogeneity_score(labels, pred)
    nmi = v_measure_score(labels, pred)

    auc, ap = model.test(z, data.test_pos_edge_index, data.test_neg_edge_index)

    return auc, ap, completeness, hm, nmi

# %% [markdown]
# ## Initialize the model

# %% [markdown]
# Initialize an encoder and a discriminator

# %%
latent_size = 32
encoder = VEncoder(data.num_features, out_channels=latent_size)

discriminator = Discriminator(in_channels=latent_size, hidden_channels=64, 
                              out_channels=1) # Comment

# %% [markdown]
# Initialize the model and move everything to the GPU

# %%
model = ARGVA(encoder, discriminator)

device = torch.device('cuda' if torch.cuda.is_available() and use_cuda else 'cpu')
model, data = model.to(device), data.to(device)

# %% [markdown]
# Define the optimizers

# %%
discriminator_optimizer = torch.optim.Adam(discriminator.parameters(), lr=0.001)
encoder_optimizer = torch.optim.Adam(encoder.parameters(), lr=0.005)

# %% [markdown]
# ### Train the model

# %%
for epoch in range(1, 201):
    loss = train()
    auc, ap, completeness, hm, nmi = test()
    print((f'Epoch: {epoch:03d}, Loss: {loss:.3f}, AUC: {auc:.3f}, '
           f'AP: {ap:.3f}, Completeness: {completeness:.3f}, '
           f'Homogeneity: {hm:.3f}, NMI: {nmi:.3f}'))
# Out:
# Epoch: 001, Loss: 5.568, AUC: 0.738, AP: 0.740, Completeness: 0.105, Homogeneity: 0.104, NMI: 0.104
# Epoch: 002, Loss: 4.763, AUC: 0.695, AP: 0.713, Completeness: 0.096, Homogeneity: 0.092, NMI: 0.094
# Epoch: 003, Loss: 4.046, AUC: 0.678, AP: 0.702, Completeness: 0.067, Homogeneity: 0.063, NMI: 0.065
# Epoch: 004, Loss: 3.520, AUC: 0.676, AP: 0.702, Completeness: 0.086, Homogeneity: 0.084, NMI: 0.085
# Epoch: 005, Loss: 3.115, AUC: 0.685, AP: 0.709, Completeness: 0.082, Homogeneity: 0.079, NMI: 0.080
# Epoch: 006, Loss: 2.828, AUC: 0.705, AP: 0.726, Completeness: 0.121, Homogeneity: 0.117, NMI: 0.119
# Epoch: 007, Loss: 2.474, AUC: 0.734, AP: 0.751, Completeness: 0.155, Homogeneity: 0.151, NMI: 0.153
# Epoch: 008, Loss: 2.245, AUC: 0.745, AP: 0.764, Completeness: 0.176, Homogeneity: 0.177, NMI: 0.176
# Epoch: 009, Loss: 2.107, AUC: 0.736, AP: 0.758, Completeness: 0.216, Homogeneity: 0.217, NMI: 0.217
# Epoch: 010, Loss: 2.022, AUC: 0.723, AP: 0.751, Completeness: 0.253, Homogeneity: 0.252, NMI: 0.252
# Epoch: 011, Loss: 2.025, AUC: 0.723, AP: 0.750, Completeness: 0.236, Homogeneity: 0.233, NMI: 0.234
# Epoch: 012, Loss: 2.085, AUC: 0.735, AP: 0.759, Completeness: 0.248, Homogeneity: 0.241, NMI: 0.245
# Epoch: 013, Loss: 2.134, AUC: 0.756, AP: 0.774, Completeness: 0.318, Homogeneity: 0.324, NMI: 0.321
# Epoch: 014, Loss: 2.152, AUC: 0.781, AP: 0.796, Completeness: 0.349, Homogeneity: 0.353, NMI: 0.351
# Epoch: 015, Loss: 2.147, AUC: 0.799, AP: 0.812, Completeness: 0.337, Homogeneity: 0.347, NMI: 0.342
# Epoch: 016, Loss: 2.162, AUC: 0.799, AP: 0.814, Completeness: 0.388, Homogeneity: 0.399, NMI: 0.394
# Epoch: 017, Loss: 2.212, AUC: 0.798, AP: 0.812, Completeness: 0.401, Homogeneity: 0.410, NMI: 0.406
# Epoch: 018, Loss: 2.348, AUC: 0.807, AP: 0.818, Completeness: 0.378, Homogeneity: 0.385, NMI: 0.381
# Epoch: 019, Loss: 2.503, AUC: 0.821, AP: 0.827, Completeness: 0.429, Homogeneity: 0.443, NMI: 0.436
# Epoch: 134, Loss: 3.697, AUC: 0.911, AP: 0.902, Completeness: 0.464, Homogeneity: 0.470, NMI: 0.467
# Epoch: 135, Loss: 3.707, AUC: 0.911, AP: 0.903, Completeness: 0.477, Homogeneity: 0.487, NMI: 0.482
# Epoch: 136, Loss: 3.687, AUC: 0.912, AP: 0.904, Completeness: 0.453, Homogeneity: 0.443, NMI: 0.448
# Epoch: 137, Loss: 3.702, AUC: 0.912, AP: 0.904, Completeness: 0.461, Homogeneity: 0.463, NMI: 0.462
# Epoch: 138, Loss: 3.663, AUC: 0.913, AP: 0.905, Completeness: 0.461, Homogeneity: 0.464, NMI: 0.463
# Epoch: 139, Loss: 3.686, AUC: 0.913, AP: 0.906, Completeness: 0.458, Homogeneity: 0.446, NMI: 0.452
# Epoch: 140, Loss: 3.625, AUC: 0.913, AP: 0.906, Completeness: 0.469, Homogeneity: 0.463, NMI: 0.466
# Epoch: 141, Loss: 3.621, AUC: 0.913, AP: 0.906, Completeness: 0.464, Homogeneity: 0.478, NMI: 0.471
# Epoch: 142, Loss: 3.782, AUC: 0.913, AP: 0.906, Completeness: 0.424, Homogeneity: 0.429, NMI: 0.427
# Epoch: 143, Loss: 3.626, AUC: 0.913, AP: 0.906, Completeness: 0.443, Homogeneity: 0.436, NMI: 0.439
# Epoch: 144, Loss: 3.605, AUC: 0.913, AP: 0.905, Completeness: 0.473, Homogeneity: 0.491, NMI: 0.482
# Epoch: 145, Loss: 3.635, AUC: 0.913, AP: 0.905, Completeness: 0.447, Homogeneity: 0.459, NMI: 0.453
# Epoch: 146, Loss: 3.623, AUC: 0.912, AP: 0.905, Completeness: 0.439, Homogeneity: 0.432, NMI: 0.436
# Epoch: 147, Loss: 3.580, AUC: 0.912, AP: 0.906, Completeness: 0.431, Homogeneity: 0.455, NMI: 0.443
# Epoch: 148, Loss: 3.660, AUC: 0.912, AP: 0.906, Completeness: 0.436, Homogeneity: 0.452, NMI: 0.444
# Epoch: 149, Loss: 3.629, AUC: 0.913, AP: 0.907, Completeness: 0.431, Homogeneity: 0.431, NMI: 0.431
# Epoch: 150, Loss: 3.629, AUC: 0.912, AP: 0.907, Completeness: 0.470, Homogeneity: 0.481, NMI: 0.475
# Epoch: 151, Loss: 3.625, AUC: 0.912, AP: 0.908, Completeness: 0.412, Homogeneity: 0.410, NMI: 0.411
# Epoch: 152, Loss: 3.682, AUC: 0.912, AP: 0.907, Completeness: 0.429, Homogeneity: 0.432, NMI: 0.430
# Epoch: 153, Loss: 3.618, AUC: 0.912, AP: 0.907, Completeness: 0.470, Homogeneity: 0.471, NMI: 0.470
# Epoch: 154, Loss: 3.642, AUC: 0.912, AP: 0.907, Completeness: 0.430, Homogeneity: 0.450, NMI: 0.440
# Epoch: 155, Loss: 3.678, AUC: 0.911, AP: 0.907, Completeness: 0.470, Homogeneity: 0.487, NMI: 0.478
# Epoch: 156, Loss: 3.514, AUC: 0.911, AP: 0.907, Completeness: 0.467, Homogeneity: 0.484, NMI: 0.475
# Epoch: 157, Loss: 3.644, AUC: 0.911, AP: 0.907, Completeness: 0.464, Homogeneity: 0.471, NMI: 0.468
# Epoch: 158, Loss: 3.585, AUC: 0.911, AP: 0.907, Completeness: 0.451, Homogeneity: 0.456, NMI: 0.453
# Epoch: 159, Loss: 3.534, AUC: 0.911, AP: 0.907, Completeness: 0.455, Homogeneity: 0.443, NMI: 0.449
# Epoch: 160, Loss: 3.572, AUC: 0.911, AP: 0.908, Completeness: 0.414, Homogeneity: 0.432, NMI: 0.423
# Epoch: 161, Loss: 3.483, AUC: 0.911, AP: 0.908, Completeness: 0.446, Homogeneity: 0.460, NMI: 0.453
# Epoch: 162, Loss: 3.549, AUC: 0.912, AP: 0.908, Completeness: 0.438, Homogeneity: 0.442, NMI: 0.440
# Epoch: 163, Loss: 3.525, AUC: 0.912, AP: 0.909, Completeness: 0.475, Homogeneity: 0.491, NMI: 0.483
# Epoch: 164, Loss: 3.517, AUC: 0.911, AP: 0.909, Completeness: 0.490, Homogeneity: 0.504, NMI: 0.497
# Epoch: 165, Loss: 3.493, AUC: 0.911, AP: 0.909, Completeness: 0.411, Homogeneity: 0.412, NMI: 0.411
# Epoch: 166, Loss: 3.502, AUC: 0.910, AP: 0.909, Completeness: 0.433, Homogeneity: 0.432, NMI: 0.433
# Epoch: 167, Loss: 3.520, AUC: 0.910, AP: 0.908, Completeness: 0.388, Homogeneity: 0.377, NMI: 0.382
# Epoch: 168, Loss: 3.472, AUC: 0.910, AP: 0.908, Completeness: 0.460, Homogeneity: 0.463, NMI: 0.461
# Epoch: 169, Loss: 3.548, AUC: 0.910, AP: 0.909, Completeness: 0.459, Homogeneity: 0.435, NMI: 0.447
# Epoch: 170, Loss: 3.471, AUC: 0.910, AP: 0.909, Completeness: 0.447, Homogeneity: 0.454, NMI: 0.450
# Epoch: 171, Loss: 3.485, AUC: 0.910, AP: 0.909, Completeness: 0.411, Homogeneity: 0.414, NMI: 0.413
# Epoch: 172, Loss: 3.532, AUC: 0.909, AP: 0.909, Completeness: 0.399, Homogeneity: 0.402, NMI: 0.401
# Epoch: 173, Loss: 3.538, AUC: 0.910, AP: 0.909, Completeness: 0.406, Homogeneity: 0.403, NMI: 0.404
# Epoch: 174, Loss: 3.490, AUC: 0.910, AP: 0.909, Completeness: 0.365, Homogeneity: 0.374, NMI: 0.369
# Epoch: 175, Loss: 3.430, AUC: 0.910, AP: 0.909, Completeness: 0.432, Homogeneity: 0.438, NMI: 0.435
# Epoch: 176, Loss: 3.456, AUC: 0.910, AP: 0.910, Completeness: 0.345, Homogeneity: 0.348, NMI: 0.347
# Epoch: 177, Loss: 3.406, AUC: 0.910, AP: 0.910, Completeness: 0.388, Homogeneity: 0.399, NMI: 0.394
# Epoch: 178, Loss: 3.506, AUC: 0.910, AP: 0.910, Completeness: 0.356, Homogeneity: 0.346, NMI: 0.351
# Epoch: 179, Loss: 3.527, AUC: 0.910, AP: 0.910, Completeness: 0.356, Homogeneity: 0.344, NMI: 0.350
# Epoch: 180, Loss: 3.549, AUC: 0.909, AP: 0.910, Completeness: 0.284, Homogeneity: 0.292, NMI: 0.288
# Epoch: 181, Loss: 3.430, AUC: 0.908, AP: 0.910, Completeness: 0.364, Homogeneity: 0.361, NMI: 0.362
# Epoch: 182, Loss: 3.539, AUC: 0.908, AP: 0.910, Completeness: 0.365, Homogeneity: 0.373, NMI: 0.369
# Epoch: 183, Loss: 3.484, AUC: 0.908, AP: 0.911, Completeness: 0.397, Homogeneity: 0.408, NMI: 0.403
# Epoch: 184, Loss: 3.451, AUC: 0.909, AP: 0.911, Completeness: 0.352, Homogeneity: 0.367, NMI: 0.359
# Epoch: 185, Loss: 3.420, AUC: 0.909, AP: 0.911, Completeness: 0.380, Homogeneity: 0.380, NMI: 0.380
# Epoch: 186, Loss: 3.455, AUC: 0.909, AP: 0.911, Completeness: 0.406, Homogeneity: 0.402, NMI: 0.404
# Epoch: 187, Loss: 3.409, AUC: 0.910, AP: 0.911, Completeness: 0.386, Homogeneity: 0.395, NMI: 0.390
# Epoch: 188, Loss: 3.393, AUC: 0.910, AP: 0.911, Completeness: 0.385, Homogeneity: 0.398, NMI: 0.391
# Epoch: 189, Loss: 3.416, AUC: 0.910, AP: 0.910, Completeness: 0.332, Homogeneity: 0.318, NMI: 0.325
# Epoch: 190, Loss: 3.384, AUC: 0.910, AP: 0.910, Completeness: 0.376, Homogeneity: 0.358, NMI: 0.367
# Epoch: 191, Loss: 3.425, AUC: 0.910, AP: 0.910, Completeness: 0.397, Homogeneity: 0.410, NMI: 0.403
# Epoch: 192, Loss: 3.396, AUC: 0.910, AP: 0.910, Completeness: 0.415, Homogeneity: 0.426, NMI: 0.421
# Epoch: 193, Loss: 3.387, AUC: 0.909, AP: 0.910, Completeness: 0.337, Homogeneity: 0.351, NMI: 0.344
# Epoch: 194, Loss: 3.345, AUC: 0.908, AP: 0.909, Completeness: 0.332, Homogeneity: 0.345, NMI: 0.339
# Epoch: 195, Loss: 3.416, AUC: 0.908, AP: 0.909, Completeness: 0.386, Homogeneity: 0.388, NMI: 0.387
# Epoch: 196, Loss: 3.397, AUC: 0.907, AP: 0.908, Completeness: 0.373, Homogeneity: 0.384, NMI: 0.378
# Epoch: 197, Loss: 3.328, AUC: 0.906, AP: 0.908, Completeness: 0.401, Homogeneity: 0.405, NMI: 0.403
# Epoch: 198, Loss: 3.418, AUC: 0.906, AP: 0.908, Completeness: 0.380, Homogeneity: 0.377, NMI: 0.378
# Epoch: 199, Loss: 3.304, AUC: 0.906, AP: 0.908, Completeness: 0.367, Homogeneity: 0.344, NMI: 0.355
# Epoch: 200, Loss: 3.346, AUC: 0.906, AP: 0.908, Completeness: 0.437, Homogeneity: 0.438, NMI: 0.438

# %%
@torch.no_grad()
def plot_points(colors):
    model.eval()
    z = model.encode(data.x, data.train_pos_edge_index)
    z = TSNE(n_components=2).fit_transform(z.cpu().numpy())
    y = data.y.cpu().numpy()

    fig = plt.figure(1, figsize=(8, 8))
    fig.clf()
    for i in range(dataset.num_classes):
        plt.scatter(z[y == i, 0], z[y == i, 1], s=20, color=colors[i])
    plt.axis('off')
    plt.show()

# %%
#%%
colors = [
    '#ffc0cb', '#bada55', '#008080', '#420420', '#7fe5f0', '#065535', '#ffd700'
]
plot_points(colors)
